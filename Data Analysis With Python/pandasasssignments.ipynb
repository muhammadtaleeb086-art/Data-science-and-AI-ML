# %% [markdown]
# # Module: Pandas Assignments
# ## Lesson: Pandas
# ### Assignment 1: DataFrame Creation and Indexing
#
# 1. Create a Pandas DataFrame with 4 columns and 6 rows filled with random integers. Set the index to be the first column.
# 2. Create a Pandas DataFrame with columns 'A', 'B', 'C' and index 'X', 'Y', 'Z'. Fill the DataFrame with random integers and access the element at row 'Y' and column 'B'.
#
# ### Assignment 2: DataFrame Operations
#
# 1. Create a Pandas DataFrame with 3 columns and 5 rows filled with random integers. Add a new column that is the product of the first two columns.
# 2. Create a Pandas DataFrame with 3 columns and 4 rows filled with random integers. Compute the row-wise and column-wise sum.
#
# ### Assignment 3: Data Cleaning
#
# 1. Create a Pandas DataFrame with 3 columns and 5 rows filled with random integers. Introduce some NaN values. Fill the NaN values with the mean of the respective columns.
# 2. Create a Pandas DataFrame with 4 columns and 6 rows filled with random integers. Introduce some NaN values. Drop the rows with any NaN values.
#
# ### Assignment 4: Data Aggregation
#
# 1. Create a Pandas DataFrame with 2 columns: 'Category' and 'Value'. Fill the 'Category' column with random categories ('A', 'B', 'C') and the 'Value' column with random integers. Group the DataFrame by 'Category' and compute the sum and mean of 'Value' for each category.
# 2. Create a Pandas DataFrame with 3 columns: 'Product', 'Category', and 'Sales'. Fill the DataFrame with random data. Group the DataFrame by 'Category' and compute the total sales for each category.
#
# ### Assignment 5: Merging DataFrames
#
# 1. Create two Pandas DataFrames with a common column. Merge the DataFrames using the common column.
# 2. Create two Pandas DataFrames with different columns. Concatenate the DataFrames along the rows and along the columns.
#
# ### Assignment 6: Time Series Analysis
#
# 1. Create a Pandas DataFrame with a datetime index and one column filled with random integers. Resample the DataFrame to compute the monthly mean of the values.
# 2. Create a Pandas DataFrame with a datetime index ranging from '2021-01-01' to '2021-12-31' and one column filled with random integers. Compute the rolling mean with a window of 7 days.
#
# ### Assignment 7: MultiIndex DataFrame
#
# 1. Create a Pandas DataFrame with a MultiIndex (hierarchical index). Perform some basic indexing and slicing operations on the MultiIndex DataFrame.
# 2. Create a Pandas DataFrame with MultiIndex consisting of 'Category' and 'SubCategory'. Fill the DataFrame with random data and compute the sum of values for each 'Category' and 'SubCategory'.
#
# ### Assignment 8: Pivot Tables
#
# 1. Create a Pandas DataFrame with columns 'Date', 'Category', and 'Value'. Create a pivot table to compute the sum of 'Value' for each 'Category' by 'Date'.
# 2. Create a Pandas DataFrame with columns 'Year', 'Quarter', and 'Revenue'. Create a pivot table to compute the mean 'Revenue' for each 'Quarter' by 'Year'.
#
# ### Assignment 9: Applying Functions
#
# 1. Create a Pandas DataFrame with 3 columns and 5 rows filled with random integers. Apply a function that doubles the values of the DataFrame.
# 2. Create a Pandas DataFrame with 3 columns and 6 rows filled with random integers. Apply a lambda function to create a new column that is the sum of the existing columns.
#
# ### Assignment 10: Working with Text Data
#
# 1. Create a Pandas Series with 5 random text strings. Convert all the strings to uppercase.
# 2. Create a Pandas Series with 5 random text strings. Extract the first three characters of each string.

# %%
## Assignment 1 : 
## Question 1 : Create a Pandas DataFrame with 4 columns and 6 rows filled with random integers. Set the index to be the first column.
import pandas as pd 
import random
import numpy as np

df = pd.DataFrame(np.random.randint(1,100,size=(6,4)),columns=['A','B','C','D'])
print("Original DataFrame")
print(df)

df.set_index('A',inplace=True)
print("Dataframe with new index")
print(df)
# Out:
# Original DataFrame
#     A   B   C   D
# 0  14  67  41  70
# 1  62  73  70  21
# 2  13  32  52  52
# 3  81  93  78  17
# 4   4  71   9  79
# 5  78  22  44  15
# Dataframe with new index
#      B   C   D
# A
# 14  67  41  70
# 62  73  70  21
# 13  32  52  52
# 81  93  78  17
# 4   71   9  79
# 78  22  44  15

# %%
## Question 2 : Create a Pandas DataFrame with columns 'A', 'B', 'C' and index 'X', 'Y', 'Z'. Fill the DataFrame with random integers and access the element at row 'Y' and column 'B'.

df = pd.DataFrame(np.random.randint(1,100,size=(3,3)),columns=['A','B','C'],index=['X','Y','Z'])
print("Original Dataframe :")
print(df)

element = df.at['Y','B']
print(f"Element at row 'Y' and column 'B' :{element} ")
# Out:
# Original Dataframe :
#     A   B   C
# X  81  34  45
# Y  65  67  12
# Z  18  10  49
# Element at row 'Y' and column 'B' :67

# %%
## Assignment 2 :
## Question 1 : Create a Pandas DataFrame with 3 columns and 5 rows filled with random integers. Add a new column that is the product of the first two columns.

df = pd.DataFrame(np.random.randint(1,100,size=(5,3)),columns=['A','B','C'])
print("Original DataFrame :")
print(df)

df['D'] = df['A'] * df['B']
print("Modified Dataframe :")
print(df)
# Out:
# Original DataFrame :
#     A   B   C
# 0  51  75  28
# 1  10  83  47
# 2  79  74  12
# 3  95   8  32
# 4   8  90  29
# Modified Dataframe :
#     A   B   C     D
# 0  51  75  28  3825
# 1  10  83  47   830
# 2  79  74  12  5846
# 3  95   8  32   760
# 4   8  90  29   720

# %%
## Question 2 : Create a Pandas DataFrame with 3 columns and 4 rows filled with random integers. Compute the row-wise and column-wise sum.

df = pd.DataFrame(np.random.randint(1,100,size=(4,3)),columns=['A','B','C'])
print("Original DataFrame :")
print(df)

row_sum  = df.sum(axis=1)
col_sum = df.sum(axis=0)

print("Row-wise Sum :")
print(row_sum)
print("Column-wise Sum :")
print(col_sum)
# Out:
# Original DataFrame :
#     A   B   C
# 0  54  43   9
# 1  88  79  26
# 2  52  67  64
# 3   6  10  80
# Row-wise Sum :
# 0    106
# 1    193
# 2    183
# 3     96
# dtype: int64
# Column-wise Sum :
# A    200
# B    199
# C    179
# dtype: int64

# %%
## Assignment 3 : 
## Question 1 : Create a Pandas DataFrame with 3 columns and 5 rows filled with random integers. Introduce some NaN values. Fill the NaN values with the mean of the respective columns.

df = pd.DataFrame(np.random.randint(1,100,size=(5,3)),columns=['A','B','C'])
print("Original Dataframe :")
print(df)

df.iloc[0,1] = np.nan
df.iloc[2,2] = np.nan
df.iloc[4,0] = np.nan

print("Data Frame with NaN:")
print(df)

df.fillna(df.mean(),inplace=True)
print("DataFrame with NaN values filled:")
print(df)
# Out:
# Original Dataframe :
#     A   B   C
# 0  65  57  56
# 1  82   1  20
# 2  14  84   3
# 3  88  25  36
# 4  40  46  34
# Data Frame with NaN:
#       A     B     C
# 0  65.0   NaN  56.0
# 1  82.0   1.0  20.0
# 2  14.0  84.0   NaN
# 3  88.0  25.0  36.0
# 4   NaN  46.0  34.0
# DataFrame with NaN values filled:
#        A     B     C
# 0  65.00  39.0  56.0
# 1  82.00   1.0  20.0
# 2  14.00  84.0  36.5
# 3  88.00  25.0  36.0
# 4  62.25  46.0  34.0

# %%
## Question 2 : Create a Pandas DataFrame with 4 columns and 6 rows filled with random integers. Introduce some NaN values. Drop the rows with any NaN values.
import pandas as pd 
import numpy as np 
df = pd.DataFrame(np.random.randint(1,100,size=(6,4)),columns=['A','B','C','D'])
print("Original Dataframe :")
print(df)

df.iloc[0,1] = np.nan
df.iloc[2,2] = np.nan
df.iloc[5,2] = np.nan 
print("DataFrame with NaN :")
print(df)

df.dropna(inplace=True)
print("DataFrame with NaN values dropped:")
print(df)
# Out:
# Original Dataframe :
#     A   B   C   D
# 0  41  65  40  27
# 1  58  74  60  40
# 2  39  83  61   1
# 3   1  26  78   7
# 4  72  50  62  14
# 5  76  38  88  26
# DataFrame with NaN :
#     A     B     C   D
# 0  41   NaN  40.0  27
# 1  58  74.0  60.0  40
# 2  39  83.0   NaN   1
# 3   1  26.0  78.0   7
# 4  72  50.0  62.0  14
# 5  76  38.0   NaN  26
# DataFrame with NaN values dropped:
#     A     B     C   D
# 1  58  74.0  60.0  40
# 3   1  26.0  78.0   7
# 4  72  50.0  62.0  14

# %%
## Assignment 4 : 
## Question 1 : Create a Pandas DataFrame with 2 columns: 'Category' and 'Value'. Fill the 'Category' column with random categories ('A', 'B', 'C') and the 'Value' column with random integers. Group the DataFrame by 'Category' and compute the sum and mean of 'Value' for each category.

df = pd.DataFrame({'Category':np.random.choice(['A','B','C','D'],size=10) , 'Value':np.random.randint(1,100,size=10)})
print("Original Dataframe :")
print(df)

grouped = df.groupby('Category')['Value'].agg(['sum','mean'])
print("Grouped Dataframe :")
print(grouped)
# Out:
# Original Dataframe :
#   Category  Value
# 0        C     80
# 1        B     71
# 2        D     56
# 3        A     11
# 4        B     35
# 5        C     60
# 6        D     46
# 7        C     33
# 8        C     29
# 9        B     30
# Grouped Dataframe :
#           sum       mean
# Category
# A          11  11.000000
# B         136  45.333333
# C         202  50.500000
# D         102  51.000000

# %%
# Question 2 : Create a Pandas DataFrame with 3 columns: 'Product', 'Category', and 'Sales'. Fill the DataFrame with random data. Group the DataFrame by 'Category' and compute the total sales for each category.
df = pd.DataFrame({'Product':np.random.choice(['Prod1','Prod2','Prod3'],size=10),'Sales':np.random.choice(['A','B','C'],size=10),'Category':np.random.randint(1,100,size=10)})
print("Original Dataframe :")
print(df)

grouped = df.groupby('Category')['Sales'].sum()
print("Grouped DataFrame :")
print(grouped)
# Out:
# Original Dataframe :
#   Product Sales  Category
# 0   Prod1     B        59
# 1   Prod2     C        62
# 2   Prod3     A         9
# 3   Prod3     B        35
# 4   Prod2     C        16
# 5   Prod3     C        18
# 6   Prod3     B        70
# 7   Prod3     C        70
# 8   Prod1     B         7
# 9   Prod2     A        70
# Grouped DataFrame :
# Category
# 7       B
# 9       A
# 16      C
# 18      C
# 35      B
# 59      B
# 62      C
# 70    BCA
# Name: Sales, dtype: object

# %%
## Assignment 5 :
## Question 1 : Create two Pandas DataFrames with a common column. Merge the DataFrames using the common column.
import pandas as pd 
import numpy as np

df1 = pd.DataFrame({'Key':['A','B','C','D'],'Value1':np.random.randint(1,100,size=4)})
df2 = pd.DataFrame({'Key':['A','B','C','D'],'Value2':np.random.randint(1,100,size=4)})
print("DataFrame 1 :")
print(df1)
print("DataFrame 2 :")
print(df2)

merged_df = pd.merge(df1,df1,on='Key')
print("Merged DataFrame :")
print(merged_df)
# Out:
# DataFrame 1 :
#   Key  Value1
# 0   A      88
# 1   B      88
# 2   C      98
# 3   D      50
# DataFrame 2 :
#   Key  Value2
# 0   A      15
# 1   B      27
# 2   C      92
# 3   D      24
# Merged DataFrame :
#   Key  Value1_x  Value1_y
# 0   A        88        88
# 1   B        88        88
# 2   C        98        98
# 3   D        50        50

# %%
## Question 2 : Create two Pandas DataFrames with different columns. Concatenate the DataFrames along the rows and along the columns.
df1 = pd.DataFrame({'A': np.random.randint(1,100,size=3),'B':np.random.randint(1,100,size=3)})
df2 = pd.DataFrame({'C': np.random.randint(1,100,size=3),'D': np.random.randint(1,100,size=3)})

print("DataFrame 1 : ")
print(df1)
print("DataFrame 2 :")
print(df2)


concat_rows = pd.concat([df1, df2], axis=0)
print("Concatenated DataFrame (rows):")
print(concat_rows)


concat_columns = pd.concat([df1, df2], axis=1)
print("Concatenated DataFrame (columns):")
print(concat_columns)
# Out:
# DataFrame 1 :
#     A   B
# 0  53  91
# 1  67  89
# 2  53  58
# DataFrame 2 :
#     C   D
# 0  33  45
# 1  99  54
# 2  21  52
# Concatenated DataFrame (rows):
#       A     B     C     D
# 0  53.0  91.0   NaN   NaN
# 1  67.0  89.0   NaN   NaN
# 2  53.0  58.0   NaN   NaN
# 0   NaN   NaN  33.0  45.0
# 1   NaN   NaN  99.0  54.0
# 2   NaN   NaN  21.0  52.0
# Concatenated DataFrame (columns):
#     A   B   C   D
# 0  53  91  33  45
# 1  67  89  99  54
# 2  53  58  21  52

# %%
## Assignment 6 :
## Question 1 : Create a Pandas DataFrame with a datetime index and one column filled with random integers. Resample the DataFrame to compute the monthly mean of the values.
import pandas as pd
import numpy as np 


date_rng = pd.date_range(start='2022-01-01', end='2022-12-31', freq='D')
df = pd.DataFrame(date_rng, columns=['date'])
df['data'] = np.random.randint(0, 100, size=(len(date_rng)))
df.set_index('date', inplace=True)
print("Original DataFrame:")
print(df)

monthly_mean = df.resample('ME').mean()
print("Monthly mean DataFrame:")
print(monthly_mean)
# Out:
# Original DataFrame:
#             data
# date
# 2022-01-01    90
# 2022-01-02    68
# 2022-01-03    57
# 2022-01-04    74
# 2022-01-05     5
# ...          ...
# 2022-12-27    22
# 2022-12-28    72
# 2022-12-29    92
# 2022-12-30    32
# 2022-12-31    36
#
# [365 rows x 1 columns]
# Monthly mean DataFrame:
#                  data
# date
# 2022-01-31  52.967742
# 2022-02-28  46.571429
# 2022-03-31  45.967742
# 2022-04-30  44.200000
# 2022-05-31  49.516129
# 2022-06-30  43.800000
# 2022-07-31  41.064516
# 2022-08-31  53.064516
# 2022-09-30  56.100000
# 2022-10-31  55.709677
# 2022-11-30  53.833333
# 2022-12-31  55.193548

# %%
# Question 2 : Create a Pandas DataFrame with a datetime index ranging from '2021-01-01' to '2021-12-31' and one column filled with random integers. Compute the rolling mean with a window of 7 days.

import pandas as pd 
import numpy as np


date_rng = pd.date_range(start='2021-01-01',end='2021-12-31',freq='D')
df = pd.DataFrame(date_rng,columns=['date'])
df['data'] = np.random.randint(0,100,size=len(date_rng))
df.set_index('date',inplace=True)
print("Original Data Frame :")
print(df)

rolling_mean = df.rolling(window=7).mean()
print("Rolling mean Data Frame :")
print(rolling_mean)
# Out:
# Original Data Frame :
#             data
# date
# 2021-01-01    10
# 2021-01-02    85
# 2021-01-03    24
# 2021-01-04    49
# 2021-01-05    54
# ...          ...
# 2021-12-27    20
# 2021-12-28     2
# 2021-12-29     6
# 2021-12-30    97
# 2021-12-31    17
#
# [365 rows x 1 columns]
# Rolling mean Data Frame :
#                  data
# date
# 2021-01-01        NaN
# 2021-01-02        NaN
# 2021-01-03        NaN
# 2021-01-04        NaN
# 2021-01-05        NaN
# ...               ...
# 2021-12-27  48.142857
# 2021-12-28  44.857143
# 2021-12-29  35.142857
# 2021-12-30  47.714286
# 2021-12-31  38.571429
#
# [365 rows x 1 columns]

# %%
# Assignment 7 : 
## Question 1 : Create a Pandas DataFrame with a MultiIndex (hierarchical index). Perform some basic indexing and slicing operations on the MultiIndex DataFrame.
import pandas as pd
import numpy as np 

arrays= [['A','B','A','B'],['one','two','one','two']]
index = pd.MultiIndex.from_arrays(arrays ,names=('Category', 'SubCategory'))
df = pd.DataFrame(np.random.randint(1,100, size=(4,3)) , index=index, columns=['Value1','Value2','Value3'])
print("MultiIndex DataFrame:")
print(df)

# Basic indexing and slicing operations
print("Indexing at Category 'A':")
print(df.loc['A'])

print("Slicing at Category 'B' and SubCategory 'two':")
print(df.loc[('B', 'two')])
# Out:
# MultiIndex DataFrame:
#                       Value1  Value2  Value3
# Category SubCategory
# A        one              39      83      70
# B        two              62      18      16
# A        one              63      88      78
# B        two              78      72      23
# Indexing at Category 'A':
#              Value1  Value2  Value3
# SubCategory
# one              39      83      70
# one              63      88      78
# Slicing at Category 'B' and SubCategory 'two':
#                       Value1  Value2  Value3
# Category SubCategory
# B        two              62      18      16
#          two              78      72      23
# C:\Users\HP\AppData\Local\Temp\ipykernel_21740\2823523257.py:17: PerformanceWarning: indexing past lexsort depth may impact performance.
#   print(df.loc[('B', 'two')])

# %%
## Question 2 : Create a Pandas DataFrame with MultiIndex consisting of 'Category' and 'SubCategory'. Fill the DataFrame with random data and compute the sum of values for each 'Category' and 'SubCategory'.

import pandas as pd 
import numpy as np 

arrays= [['A','B','A','B'],['one','two','one','two']]
index = pd.MultiIndex.from_arrays(arrays ,names=('Category', 'SubCategory'))
df = pd.DataFrame(np.random.randint(1,100, size=(4,3)) , index=index, columns=['Value1','Value2','Value3'])
print("MultiIndex DataFrame:")
print(df)


sum_values = df.groupby(['Category', 'SubCategory']).sum()
print("Sum of values:")
print(sum_values)
# Out:
# MultiIndex DataFrame:
#                       Value1  Value2  Value3
# Category SubCategory
# A        one              61      61       1
# B        two              90      93      81
# A        one              49      79      67
# B        two               8      59      52
# Sum of values:
#                       Value1  Value2  Value3
# Category SubCategory
# A        one             110     140      68
# B        two              98     152     133

# %%
## Assignment 8 : 
## Question 1 : Create a Pandas DataFrame with columns 'Date', 'Category', and 'Value'. Create a pivot table to compute the sum of 'Value' for each 'Category' by 'Date'.
import pandas as pd 
import numpy as np 

date_rng = pd.date_range(start='2026-01-01', end='2026-01-10', freq='D')
df = pd.DataFrame({'Date': np.random.choice(date_rng, size=20), 'Category': np.random.choice(['A', 'B', 'C'], size=20), 'Value': np.random.randint(1, 100, size=20)})
print("Original DataFrame:")
print(df)

pivot_table = df.pivot_table(values='Value', index='Date', columns='Category', aggfunc='sum')
print("Pivot Table:")
print(pivot_table)
# Out:
# Original DataFrame:
#          Date Category  Value
# 0  2026-01-05        B     79
# 1  2026-01-10        C     79
# 2  2026-01-07        A     16
# 3  2026-01-05        B     66
# 4  2026-01-06        C     12
# 5  2026-01-05        C     11
# 6  2026-01-02        C     67
# 7  2026-01-03        B      9
# 8  2026-01-05        B     59
# 9  2026-01-10        A     21
# 10 2026-01-05        A     63
# 11 2026-01-01        A     41
# 12 2026-01-05        B     56
# 13 2026-01-04        A     48
# 14 2026-01-04        C     11
# 15 2026-01-07        C     14
# 16 2026-01-03        A     21
# 17 2026-01-09        C     82
# 18 2026-01-04        A     71
# 19 2026-01-06        C     50
# Pivot Table:
# Category        A      B     C
# Date
# 2026-01-01   41.0    NaN   NaN
# 2026-01-02    NaN    NaN  67.0
# 2026-01-03   21.0    9.0   NaN
# 2026-01-04  119.0    NaN  11.0
# 2026-01-05   63.0  260.0  11.0
# 2026-01-06    NaN    NaN  62.0
# 2026-01-07   16.0    NaN  14.0
# 2026-01-09    NaN    NaN  82.0
# 2026-01-10   21.0    NaN  79.0

# %%
## Question 2 :  Create a Pandas DataFrame with columns 'Year', 'Quarter', and 'Revenue'. Create a pivot table to compute the mean 'Revenue' for each 'Quarter' by 'Year'.
df = pd.DataFrame({'Year': np.random.choice([2020, 2021, 2022], size=12), 'Quarter': np.random.choice(['Q1', 'Q2', 'Q3', 'Q4'], size=12), 'Revenue': np.random.randint(1, 1000, size=12)})
print("Original DataFrame:")
print(df)


pivot_table = df.pivot_table(values='Revenue', index='Year', columns='Quarter', aggfunc='mean')
print("Pivot Table:")
print(pivot_table)
# Out:
# Original DataFrame:
#     Year Quarter  Revenue
# 0   2022      Q2      850
# 1   2020      Q4        9
# 2   2020      Q1      720
# 3   2022      Q3      439
# 4   2020      Q4      977
# 5   2021      Q1      475
# 6   2022      Q1      760
# 7   2022      Q3       57
# 8   2022      Q4      632
# 9   2022      Q1      970
# 10  2022      Q4      907
# 11  2022      Q4      299
# Pivot Table:
# Quarter     Q1     Q2     Q3          Q4
# Year
# 2020     720.0    NaN    NaN  493.000000
# 2021     475.0    NaN    NaN         NaN
# 2022     865.0  850.0  248.0  612.666667

# %%
## Assignment 9 :
## Question : 1. Create a Pandas DataFrame with 3 columns and 5 rows filled with random integers. Apply a function that doubles the values of the DataFrame.
df = pd.DataFrame(np.random.randint(1, 100, size=(5, 3)), columns=['A', 'B', 'C'])
print("Original DataFrame:")
print(df)


df_doubled = df.applymap(lambda x: x * 2)
print("Doubled DataFrame:")
print(df_doubled)
# Out:
# Original DataFrame:
#     A   B   C
# 0  78  54  97
# 1   2  91  58
# 2  76  75  33
# 3  12  46  84
# 4  34  54  58
# Doubled DataFrame:
#      A    B    C
# 0  156  108  194
# 1    4  182  116
# 2  152  150   66
# 3   24   92  168
# 4   68  108  116
# C:\Users\HP\AppData\Local\Temp\ipykernel_9832\4057475534.py:8: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_doubled = df.applymap(lambda x: x * 2)

# %%
## Question : 2. Create a Pandas DataFrame with 3 columns and 6 rows filled with random integers. Apply a lambda function to create a new column that is the sum of the existing columns.
df = pd.DataFrame(np.random.randint(1, 100, size=(6, 3)), columns=['A', 'B', 'C'])
print("Original DataFrame:")
print(df)


df['Sum'] = df.apply(lambda row: row.sum(), axis=1)
print("DataFrame with Sum column:")
print(df)
# Out:
# Original DataFrame:
#     A   B   C
# 0  47   2   2
# 1  25  65  70
# 2  67  45  75
# 3  42  45  82
# 4  80  75  65
# 5  47  16  35
# DataFrame with Sum column:
#     A   B   C  Sum
# 0  47   2   2   51
# 1  25  65  70  160
# 2  67  45  75  187
# 3  42  45  82  169
# 4  80  75  65  220
# 5  47  16  35   98

# %%
## Assignment 10 :
## Question : 1. Create a Pandas Series with 5 random text strings. Convert all the strings to uppercase.
text_data = pd.Series(['apple', 'banana', 'cherry', 'date', 'elderberry'])
print("Original Series:")
print(text_data)


uppercase_data = text_data.str.upper()
print("Uppercase Series:")
print(uppercase_data)
# Out:
# Original Series:
# 0         apple
# 1        banana
# 2        cherry
# 3          date
# 4    elderberry
# dtype: object
# Uppercase Series:
# 0         APPLE
# 1        BANANA
# 2        CHERRY
# 3          DATE
# 4    ELDERBERRY
# dtype: object

# %%
## Question : 2. Create a Pandas Series with 5 random text strings. Extract the first three characters of each string.

text_data = pd.Series(['apple', 'banana', 'cherry', 'date', 'elderberry'])
print("Original Series:")
print(text_data)


first_three_chars = text_data.str[:3]
print("First three characters:")
print(first_three_chars)
# Out:
# Original Series:
# 0         apple
# 1        banana
# 2        cherry
# 3          date
# 4    elderberry
# dtype: object
# First three characters:
# 0    app
# 1    ban
# 2    che
# 3    dat
# 4    eld
# dtype: object
