# %% [markdown]
# ## Reading Data From Different Sources

# %%
import pandas as pd
from io import StringIO
Data = '{"Employee_name": "James", "Email": "james@gmail.com", "Job_profile": {"title1": "Team Lead", "title2": "Sr Developer"}}'
df = pd.read_json(StringIO(Data))

# %%
df
# Out:
#        Employee_name            Email   Job_profile
# title1         James  james@gmail.com     Team Lead
# title2         James  james@gmail.com  Sr Developer

# %%
df.to_json() # Convert DataFrame to JSON string
# Out:
# '{"Employee_name":{"title1":"James","title2":"James"},"Email":{"title1":"james@gmail.com","title2":"james@gmail.com"},"Job_profile":{"title1":"Team Lead","title2":"Sr Developer"}}'

# %%
df.to_json(orient='index') # Convert DataFrame to JSON string with index orientation
# Out:
# '{"title1":{"Employee_name":"James","Email":"james@gmail.com","Job_profile":"Team Lead"},"title2":{"Employee_name":"James","Email":"james@gmail.com","Job_profile":"Sr Developer"}}'

# %%
df.to_json(orient='records') # Convert DataFrame to JSON string with 'records' orientation
# Out:
# '[{"Employee_name":"James","Email":"james@gmail.com","Job_profile":"Team Lead"},{"Employee_name":"James","Email":"james@gmail.com","Job_profile":"Sr Developer"}]'

# %%
# !pip install lxml
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/4.0 MB 1.1 MB/s eta 0:00:04
#    ------- -------------------------------- 0.8/4.0 MB 1.2 MB/s eta 0:00:03
#    ------------- -------------------------- 1.3/4.0 MB 1.4 MB/s eta 0:00:02
#    --------------- ------------------------ 1.6/4.0 MB 1.4 MB/s eta 0:00:02
#    ------------------ --------------------- 1.8/4.0 MB 1.5 MB/s eta 0:00:02
# ...

# %%
# !pip install html5lib
# !pip install beautifulsoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000016121056120>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/beautifulsoup4/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000016121051D10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/beautifulsoup4/
# ...

# %%
url = "https://www.fdic.gov/bank-failures/failed-bank-list"

df = pd.read_html(url)

# %%
df[0]
# Out:
#                                             Bank Name                City  \
# 0                   Metropolitan Capital Bank & Trust             Chicago
# 1                        The Santa Anna National Bank          Santa Anna
# 2                                Pulaski Savings Bank             Chicago
# 3                  The First National Bank of Lindsay             Lindsay
# 4               Republic First Bank dba Republic Bank        Philadelphia
# 5                                       Citizens Bank            Sac City
# 6                            Heartland Tri-State Bank             Elkhart
# 7                                 First Republic Bank       San Francisco
# 8                                      Signature Bank            New York
# 9                                 Silicon Valley Bank         Santa Clara
# 10                                  Almena State Bank              Almena
# 11                         First City Bank of Florida   Fort Walton Beach
# ...

# %%
# %pip install requests

# %%
import requests
import pandas as pd

url = 'https://en.wikipedia.org/wiki/Mobile_country_code'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
response = requests.get(url, headers=headers)
tables = pd.read_html(response.text, match="Country", header=0)
df = tables[0]
print(df.head())
# Out:
#    Mobile country code                                    Country ISO 3166  \
# 0                  289                                 A Abkhazia    GE-AB
# 1                  412                                Afghanistan       AF
# 2                  276                                    Albania       AL
# 3                  603                                    Algeria       DZ
# 4                  544  American Samoa (United States of America)       AS
#
#                              Mobile network codes National MNC authority  \
# 0        List of mobile network codes in Abkhazia                    NaN
# 1     List of mobile network codes in Afghanistan                    NaN
# 2         List of mobile network codes in Albania                    NaN
# 3         List of mobile network codes in Algeria                    NaN
# 4  List of mobile network codes in American Samoa                    NaN
#
#                     Remarks
# 0  MCC is not listed by ITU
# ...
